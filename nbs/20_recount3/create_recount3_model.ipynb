# %% [markdown]
# # Create recount3 model

# %% [markdown]
# Marc Subirana-Granés (2024)
#
# Description

# %% [markdown]
# # Load libraries/modules

# %%
# Load libraries/modules
library(recount3)
library(PLIER)
library(here)
library(dplyr)
library(rhdf5)
library(HDF5Array)
library(glmnet)
library(biomaRt)

# Load PLIER pathway and cell type data
data(bloodCellMarkersIRISDMAP)
data(svmMarkers)
data(canonicalPathways)
data(chemgenPathways)
data(oncogenicPathways)
data(xCell)
data(immunePathways)
chr21_pathway <- readRDS(here::here('output/pathways/chr21_pathway.rds'))

#delayedPLIER functions from repo
path_script_funcs = '/home/msubirana/Documents/pivlab/DelayedPLIER/funcs.R'
source(path_script_funcs)

# %% [markdown]
# # Load data

# %%
# Define output nb path
output_nb_path <- here("output/nbs/create_recount3_model")

# Create directory if it doesn't exist
if (!dir.exists(output_nb_path)) {
  dir.create(output_nb_path, recursive = TRUE)
}

# %% [markdown]
# ## Download recount3

# %%
available_samples()
# Out:
# 2024-06-21 18:36:08.219283 caching file sra.recount_project.MD.gz.
#
# 2024-06-21 18:36:08.73041 caching file gtex.recount_project.MD.gz.
#
# 2024-06-21 18:36:09.282253 caching file tcga.recount_project.MD.gz.
#        external_id                          project   organism file_source
# 1      SRR5579327                           SRP107565 human    sra
# 2      SRR5579328                           SRP107565 human    sra
# 3      SRR5579329                           SRP107565 human    sra
# 4      SRR5579330                           SRP107565 human    sra
# 5      SRR5579331                           SRP107565 human    sra
# 6      SRR5579332                           SRP107565 human    sra
# 7      SRR5579333                           SRP107565 human    sra
# 8      SRR5579334                           SRP107565 human    sra
# 9      SRR5579335                           SRP107565 human    sra
# 10     SRR5579336                           SRP107565 human    sra
# 11     SRR5579337                           SRP107565 human    sra
# 12     SRR5579338                           SRP107565 human    sra
# 13     SRR5579339                           SRP107565 human    sra
# 14     SRR5579340                           SRP107565 human    sra
# 15     SRR5579341                           SRP107565 human    sra
# 16     SRR5579342                           SRP107565 human    sra
# 17     SRR5579343                           SRP107565 human    sra
# 18     SRR5579344                           SRP107565 human    sra
# 19     SRR5579345                           SRP107565 human    sra
# 20     SRR5579346                           SRP107565 human    sra
# 21     SRR5579347                           SRP107565 human    sra
# 22     SRR5579348                           SRP107565 human    sra
# 23     SRR5579349                           SRP107565 human    sra
# 24     SRR5579350                           SRP107565 human    sra
# 25     SRR5579351                           SRP107565 human    sra
# 26     SRR5579352                           SRP107565 human    sra
# 27     SRR5579353                           SRP107565 human    sra
# 28     SRR5579354                           SRP107565 human    sra
# 29     SRR5579355                           SRP107565 human    sra
# 30     SRR5579356                           SRP107565 human    sra
# ⋮      ⋮                                    ⋮         ⋮        ⋮
# 346976 b76db955-69b7-4d05-8166-2569ed44628c UVM       human    tcga
# 346977 b837d582-a0d3-46be-8eca-883f5396ae88 UVM       human    tcga
# 346978 ba016f57-f58f-4a66-b85a-0b0f911eea65 UVM       human    tcga
# 346979 bb948be8-7d48-4aeb-a404-c27a79655d7e UVM       human    tcga
# 346980 bc761676-f64c-476a-8d9b-bd3e6149b2cd UVM       human    tcga
# 346981 bcfcbbac-eb95-47eb-9eb0-2cb4ae283a75 UVM       human    tcga
# 346982 c45eb423-cc14-4bdb-a0b4-447e5db6da9c UVM       human    tcga
# 346983 c8c48afd-4d8b-491e-993c-3506dc6dd00f UVM       human    tcga
# 346984 cb35ded2-5fea-43e2-ab42-b6b3a7444b66 UVM       human    tcga
# 346985 cfb8573c-9f36-4715-b6f1-6e5b543168a8 UVM       human    tcga
# 346986 d0758a7a-9d0e-4ea4-8ee9-7143b398647d UVM       human    tcga
# 346987 d34b0bc6-9142-48ae-a113-5923192644a0 UVM       human    tcga
# 346988 d357ac5c-c2a0-4cc4-b016-4572400af117 UVM       human    tcga
# 346989 d3fc3968-b263-4756-bf7f-1941f70b04da UVM       human    tcga
# 346990 d6365feb-cc12-4337-bf8c-66236a585b5d UVM       human    tcga
# 346991 d8351e5c-dc1d-4b4d-83e6-735b2750d944 UVM       human    tcga
# 346992 da00d60f-4cf1-4003-baf5-896ee2bee2d4 UVM       human    tcga
# 346993 db676839-02aa-42a7-962f-89d6ad892008 UVM       human    tcga
# 346994 dea60b47-ad6a-4ebb-9402-6f97e9640e4e UVM       human    tcga
# 346995 e226c45e-5287-4d0f-a34b-ce251fa293cb UVM       human    tcga
# 346996 e25c9578-9493-466e-a2cd-546deb076b2d UVM       human    tcga
# 346997 e6e08c1a-4c1b-4572-92df-da15bcbadf76 UVM       human    tcga
# 346998 ea35e230-de50-45ab-a737-d5c430652a90 UVM       human    tcga
# 346999 eec6da0c-5c49-4efe-976a-19f432ddaa58 UVM       human    tcga
# 347000 ef1a102f-c206-4874-8f27-0bf069a613b8 UVM       human    tcga
# 347001 efc730ec-6385-4167-a65a-f2a3aaeda2ac UVM       human    tcga
# 347002 effccf33-60e1-4550-b13c-14c54adcf479 UVM       human    tcga
# 347003 f2995599-3f21-4f33-92bb-7d70a4735938 UVM       human    tcga
# 347004 f400fd4d-72d7-4933-b145-64b7ee245ffc UVM       human    tcga
# 347005 f5b9b89b-6821-43ee-bcfd-623689d03af9 UVM       human    tcga
#        date_processed project_home      project_type
# 1      2019-10-01     data_sources/sra  data_sources
# 2      2019-10-01     data_sources/sra  data_sources
# 3      2019-10-01     data_sources/sra  data_sources
# 4      2019-10-01     data_sources/sra  data_sources
# 5      2019-10-01     data_sources/sra  data_sources
# 6      2019-10-01     data_sources/sra  data_sources
# 7      2019-10-01     data_sources/sra  data_sources
# 8      2019-10-01     data_sources/sra  data_sources
# 9      2019-10-01     data_sources/sra  data_sources
# 10     2019-10-01     data_sources/sra  data_sources
# 11     2019-10-01     data_sources/sra  data_sources
# 12     2019-10-01     data_sources/sra  data_sources
# 13     2019-10-01     data_sources/sra  data_sources
# 14     2019-10-01     data_sources/sra  data_sources
# 15     2019-10-01     data_sources/sra  data_sources
# 16     2019-10-01     data_sources/sra  data_sources
# 17     2019-10-01     data_sources/sra  data_sources
# 18     2019-10-01     data_sources/sra  data_sources
# 19     2019-10-01     data_sources/sra  data_sources
# 20     2019-10-01     data_sources/sra  data_sources
# 21     2019-10-01     data_sources/sra  data_sources
# 22     2019-10-01     data_sources/sra  data_sources
# 23     2019-10-01     data_sources/sra  data_sources
# 24     2019-10-01     data_sources/sra  data_sources
# 25     2019-10-01     data_sources/sra  data_sources
# 26     2019-10-01     data_sources/sra  data_sources
# 27     2019-10-01     data_sources/sra  data_sources
# 28     2019-10-01     data_sources/sra  data_sources
# 29     2019-10-01     data_sources/sra  data_sources
# 30     2019-10-01     data_sources/sra  data_sources
# ⋮      ⋮              ⋮                 ⋮
# 346976 2019-12-01     data_sources/tcga data_sources
# 346977 2019-12-01     data_sources/tcga data_sources
# 346978 2019-12-01     data_sources/tcga data_sources
# 346979 2019-12-01     data_sources/tcga data_sources
# 346980 2019-12-01     data_sources/tcga data_sources
# 346981 2019-12-01     data_sources/tcga data_sources
# 346982 2019-12-01     data_sources/tcga data_sources
# 346983 2019-12-01     data_sources/tcga data_sources
# 346984 2019-12-01     data_sources/tcga data_sources
# 346985 2019-12-01     data_sources/tcga data_sources
# 346986 2019-12-01     data_sources/tcga data_sources
# 346987 2019-12-01     data_sources/tcga data_sources
# 346988 2019-12-01     data_sources/tcga data_sources
# 346989 2019-12-01     data_sources/tcga data_sources
# 346990 2019-12-01     data_sources/tcga data_sources
# 346991 2019-12-01     data_sources/tcga data_sources
# 346992 2019-12-01     data_sources/tcga data_sources
# 346993 2019-12-01     data_sources/tcga data_sources
# 346994 2019-12-01     data_sources/tcga data_sources
# 346995 2019-12-01     data_sources/tcga data_sources
# 346996 2019-12-01     data_sources/tcga data_sources
# 346997 2019-12-01     data_sources/tcga data_sources
# 346998 2019-12-01     data_sources/tcga data_sources
# 346999 2019-12-01     data_sources/tcga data_sources
# 347000 2019-12-01     data_sources/tcga data_sources
# 347001 2019-12-01     data_sources/tcga data_sources
# 347002 2019-12-01     data_sources/tcga data_sources
# 347003 2019-12-01     data_sources/tcga data_sources
# 347004 2019-12-01     data_sources/tcga data_sources
# 347005 2019-12-01     data_sources/tcga data_sources

# %% [markdown]
# # Qiwen Hu - 2017
#
# # Processing all recounts datasets
#
# # genes expression are normalized by RPKM
#
# # It can be run from the command line using
#
# # Rscript recount2/1-get_all_recount_dataset.R
#
# #
#
# # Output:
#
# # Normalized gene expression for each sample
#
# `%>%` <- dplyr::`%>%`
# library(recount)
#
# # Get RPKM value for each gene - adapted from recount package
#
# getRPKM <- function(rse, length_var = 'bp_length', mapped_var = NULL) {
#
# # Computes the RPKM value for each gene in the sample.
#
# #
#
# # Args:
#
# # rse: A RangedSummarizedExperiment-class object in recount package
#
# # length_var: A length 1 character vector with the column name from rowData(rse) that has
#
# # the coding length. For gene level objects from recount this is bp_length. If
#
# # NULL, then it will use width(rowRanges(rse)) which should be used for exon RSEs.
#
# # mapped_var: A length 1 character vector with the column name from colData(rse) that has
#
# # the number of reads mapped. If NULL (default) then it will use the column
#
# # sums of the counts matrix
#
# # Returns:
#
# # RPKM value for each sample
#
# if(!is.null(mapped_var)){
# mapped <- colData(rse)[, mapped_var]
# } else {
# mapped <- colSums(assays(rse)$counts)
#   }
#   bg <- matrix(mapped, ncol = ncol(rse), nrow = nrow(rse), byrow = TRUE)
#   if(!is.null(length_var)){
#     len <- rowData(rse)[, length_var]
#   } else {
#     len <- width(rowRanges(rse))
#   }
#   wid <- matrix(len, nrow = nrow(rse), ncol = ncol(rse), byrow = FALSE)
#   rpkm <- assays(rse)$counts / (wid/1000) / (bg/1e6)
# return(rpkm)
# }
#
# data.dir <- file.path("recount2", "data")
# dir.create(data.dir, recursive = TRUE, showWarnings = FALSE)
#
# # Get all samples from recount database
#
# metasample.sra <- all_metadata(subset = "sra", verbose = TRUE)
# metasample.sra <- as.data.frame(metasample.sra)
#
# # Remove samples without description
#
# metadata.nonempty <- metasample.sra[!is.na(metasample.sra$characteristics), ]
# included.sample.list <- unique(metadata.nonempty$project)
#
# # Download all recount2 samples in included.sample.list
#
# lapply(included.sample.list,
# function(x) download_study(x, type = "rse-gene",
# outdir = file.path(data.dir, x)))
#
# # get RPKM for each experiment and add to list
#
# rpkm.list <- list()
# for(experiment in included.sample.list) {
# load(file.path(data.dir, experiment, 'rse_gene.Rdata'))
# rpkm <- as.data.frame(getRPKM(rse_gene))
# rpkm$id <- rownames(rpkm)
# rpkm.list[[experiment]] <- rpkm
# }
#
# # combine experiments -- this is the most memory efficient way to go about this
#
# # that I've found -- will need to drop extraneous gene id columns
#
# rpkm.df <- do.call(base::cbind, c(rpkm.list, by = "id"))
# rpkm.df <- rpkm.df %>% dplyr::select(-dplyr::ends_with("id"))
# rpkm.df <- tibble::rownames_to_column(rpkm.df, "ENSG")
#
# # drop last column "by" -- information about what was used with base::cbind
#
# rpkm.df <- rpkm.df %>% dplyr::select(-by)
#
# # save to file
#
# saveRDS(rpkm.df, file = file.path("recount2", "recount_rpkm.RDS"))

# %%
human_projects <- available_projects("human")
human_projects <- human_projects[1:25,]
# Out:
# 2024-06-21 18:36:10.640203 caching file sra.recount_project.MD.gz.
#
# 2024-06-21 18:36:11.104776 caching file gtex.recount_project.MD.gz.
#
# 2024-06-21 18:36:11.54756 caching file tcga.recount_project.MD.gz.

# %%
human_projects
sum(human_projects$n_samples)
# Out:
#    project   organism file_source project_home     project_type n_samples
# 1  SRP107565 human    sra         data_sources/sra data_sources 216
# 2  SRP149665 human    sra         data_sources/sra data_sources   4
# 3  SRP017465 human    sra         data_sources/sra data_sources  23
# 4  SRP119165 human    sra         data_sources/sra data_sources   6
# 5  SRP133965 human    sra         data_sources/sra data_sources  12
# 6  SRP096765 human    sra         data_sources/sra data_sources   7
# 7  SRP124965 human    sra         data_sources/sra data_sources  12
# 8  SRP189165 human    sra         data_sources/sra data_sources  15
# 9  SRP050365 human    sra         data_sources/sra data_sources  10
# 10 SRP123065 human    sra         data_sources/sra data_sources  41
# 11 SRP162465 human    sra         data_sources/sra data_sources   8
# 12 SRP178865 human    sra         data_sources/sra data_sources  24
# 13 SRP032165 human    sra         data_sources/sra data_sources  24
# 14 SRP125965 human    sra         data_sources/sra data_sources  72
# 15 SRP120165 human    sra         data_sources/sra data_sources  18
# 16 SRP044265 human    sra         data_sources/sra data_sources   6
# 17 SRP014565 human    sra         data_sources/sra data_sources   1
# 18 SRP057065 human    sra         data_sources/sra data_sources  51
# 19 SRP117665 human    sra         data_sources/sra data_sources   9
# 20 SRP049465 human    sra         data_sources/sra data_sources   4
# 21 SRP007665 human    sra         data_sources/sra data_sources   1
# 22 SRP124265 human    sra         data_sources/sra data_sources   2
# 23 SRP187765 human    sra         data_sources/sra data_sources  14
# 24 SRP157965 human    sra         data_sources/sra data_sources  63
# 25 SRP150065 human    sra         data_sources/sra data_sources  18
# [1] 661

# %%
recount3_h5 <- file.path(output_nb_path, "recount3_dataset_tpm.h5")
h5createFile(recount3_h5)

# %%
ensembl <- useMart("ensembl", dataset = "hsapiens_gene_ensembl")

# %%
# Define the function to load data and calculate TPM
process_project <- function(proj_info) {
    # Load project data
    rse <- recount3::create_rse(proj_info)
    
    # Ensure 'counts' field exists and is set to 'raw_counts' if necessary
    if (!"counts" %in% names(assays(rse))) {
        assays(rse)$counts <- assays(rse)$raw_counts
        assays(rse)$raw_counts <- NULL
    }
    
    # Calculate TPM and return the TPM matrix
    assays(rse)$TPM <- recount::getTPM(rse)
    return(assays(rse)$TPM)
}

# Initialize the HDF5 file and dataset
h5createFile(recount3_h5)

# Define initial dimensions assuming the first project has the correct dimensions
initial_proj_info <- human_projects[1, , drop = FALSE]
initial_matrix <- process_project(initial_proj_info)

rownames(initial_matrix) <- gsub("\\..*$", "", rownames(initial_matrix))
gene_ids <- rownames(initial_matrix)

gene_info <- getBM(attributes = c("ensembl_gene_id", "hgnc_symbol"),
                   filters = "ensembl_gene_id",
                   values = gene_ids,
                   mart = ensembl)

rownames(initial_matrix) <- gsub("\\..*$", "", rownames(initial_matrix))
    df_initial_matrix = data.frame(initial_matrix)
    df_initial_matrix <- df_initial_matrix %>%
    tibble::rownames_to_column(var = "ensembl_gene_id")
    # filter to remove genes without a gene symbol
    gene_info <- gene_info %>% dplyr::filter(complete.cases(.))
    # add gene symbols to expression df
    df_initial_matrix <- dplyr::inner_join(gene_info, df_initial_matrix, 
                                by = "ensembl_gene_id")
    df_initial_matrix <- df_initial_matrix %>%
        dplyr::filter(hgnc_symbol != '') %>%
        distinct(hgnc_symbol, .keep_all = TRUE) %>%
        tibble::column_to_rownames(var = "hgnc_symbol") %>%
        subset(select = -c(ensembl_gene_id))

    initial_matrix <- as.matrix(df_initial_matrix)

total_rows <- nrow(initial_matrix)

total_columns <- sum(sapply(1:nrow(human_projects), function(i) {
    ncol(process_project(human_projects[i, , drop = FALSE]))
}))

h5createDataset(recount3_h5, "count", 
                dims = c(total_rows, total_columns), 
                maxdims = c(total_rows, total_columns), 
                storage.mode = "double", 
                chunk = c(total_rows, 1000)) 

# Process and write each matrix sequentially
start_col <- 1

all_colnames <- c()

for (i in 1:nrow(human_projects)) {

    proj_info <- human_projects[i, , drop = FALSE]
    matrix <- process_project(proj_info)

    # id to symbols

    rownames(matrix) <- gsub("\\..*$", "", rownames(matrix))
    df_matrix = data.frame(matrix)
    df_matrix <- df_matrix %>%
    tibble::rownames_to_column(var = "ensembl_gene_id")
    # filter to remove genes without a gene symbol
    gene_info <- gene_info %>% dplyr::filter(complete.cases(.))
    # add gene symbols to expression df
    df_matrix <- dplyr::inner_join(gene_info, df_matrix, 
                                by = "ensembl_gene_id")
    df_matrix <- df_matrix %>%
        dplyr::filter(hgnc_symbol != '') %>%
        distinct(hgnc_symbol, .keep_all = TRUE) %>%
        tibble::column_to_rownames(var = "hgnc_symbol") %>%
        subset(select = -c(ensembl_gene_id))

    matrix <- as.matrix(df_matrix)

    end_col <- start_col + ncol(matrix) - 1
    h5write(matrix, recount3_h5, "count", 
            index = list(1:total_rows, start_col:end_col))
    start_col <- end_col + 1
    all_colnames <- c(all_colnames, colnames(matrix))
}
# Out:
# file '/home/msubirana/Documents/pivlab/plier_recount3/output/nbs/create_recount3_model/recount3_dataset_tpm.h5' already exists.
#
# 2024-06-21 18:36:15.440184 downloading and reading the metadata.
# 2024-06-21 18:36:15.793949 caching file sra.sra.SRP107565.MD.gz.
#
# 2024-06-21 18:36:16.341716 caching file sra.recount_project.SRP107565.MD.gz.
#
# 2024-06-21 18:36:16.906145 caching file sra.recount_qc.SRP107565.MD.gz.
#
# 2024-06-21 18:36:17.435856 caching file sra.recount_seq_qc.SRP107565.MD.gz.
#
# Warning message:
# “The 'url' <http://duffel.rail.bio/recount3/human/data_sources/sra/metadata/65/SRP107565/sra.recount_pred.SRP107565.MD.gz> does not exist or is not available.”
# 2024-06-21 18:36:17.927135 downloading and reading the feature information.
#
# 2024-06-21 18:36:18.315335 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:36:18.761522 downloading and reading the counts: 216 samples across 63856 features.
#
# 2024-06-21 18:36:19.109067 caching file sra.gene_sums.SRP107565.G026.gz.
#
# 2024-06-21 18:36:19.689796 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:36:22.699106 downloading and reading the metadata.
#
# 2024-06-21 18:36:23.109608 caching file sra.sra.SRP107565.MD.gz.
#
# 2024-06-21 18:36:23.513381 caching file sra.recount_project.SRP107565.MD.gz.
#
# 2024-06-21 18:36:23.907543 caching file sra.recount_qc.SRP107565.MD.gz.
#
# 2024-06-21 18:36:24.303262 caching file sra.recount_seq_qc.SRP107565.MD.gz.
#
# Warning message:
# “The 'url' <http://duffel.rail.bio/recount3/human/data_sources/sra/metadata/65/SRP107565/sra.recount_pred.SRP107565.MD.gz> does not exist or is not available.”
# 2024-06-21 18:36:24.754646 downloading and reading the feature information.
#
# 2024-06-21 18:36:25.008413 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:36:25.384247 downloading and reading the counts: 216 samples across 63856 features.
#
# 2024-06-21 18:36:25.658371 caching file sra.gene_sums.SRP107565.G026.gz.
#
# 2024-06-21 18:36:26.204953 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:36:27.900046 downloading and reading the metadata.
#
# 2024-06-21 18:36:28.17122 caching file sra.sra.SRP149665.MD.gz.
#
# 2024-06-21 18:36:28.672365 caching file sra.recount_project.SRP149665.MD.gz.
#
# 2024-06-21 18:36:29.182374 caching file sra.recount_qc.SRP149665.MD.gz.
#
# 2024-06-21 18:36:29.705086 caching file sra.recount_seq_qc.SRP149665.MD.gz.
#
# 2024-06-21 18:36:30.231413 caching file sra.recount_pred.SRP149665.MD.gz.
#
# 2024-06-21 18:36:30.38378 downloading and reading the feature information.
#
# 2024-06-21 18:36:30.708336 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:36:31.121254 downloading and reading the counts: 4 samples across 63856 features.
#
# 2024-06-21 18:36:31.479799 caching file sra.gene_sums.SRP149665.G026.gz.
#
# 2024-06-21 18:36:31.701286 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:36:31.825946 downloading and reading the metadata.
#
# 2024-06-21 18:36:32.183696 caching file sra.sra.SRP017465.MD.gz.
#
# 2024-06-21 18:36:32.684795 caching file sra.recount_project.SRP017465.MD.gz.
#
# 2024-06-21 18:36:33.225502 caching file sra.recount_qc.SRP017465.MD.gz.
#
# 2024-06-21 18:36:33.72841 caching file sra.recount_seq_qc.SRP017465.MD.gz.
#
# 2024-06-21 18:36:34.229669 caching file sra.recount_pred.SRP017465.MD.gz.
#
# 2024-06-21 18:36:34.401712 downloading and reading the feature information.
#
# 2024-06-21 18:36:34.642813 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:36:35.044344 downloading and reading the counts: 23 samples across 63856 features.
#
# 2024-06-21 18:36:35.43061 caching file sra.gene_sums.SRP017465.G026.gz.
#
# 2024-06-21 18:36:35.681431 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:36:35.772839 downloading and reading the metadata.
#
# 2024-06-21 18:36:36.055262 caching file sra.sra.SRP119165.MD.gz.
#
# 2024-06-21 18:36:36.581329 caching file sra.recount_project.SRP119165.MD.gz.
#
# 2024-06-21 18:36:37.025317 caching file sra.recount_qc.SRP119165.MD.gz.
#
# 2024-06-21 18:36:37.564454 caching file sra.recount_seq_qc.SRP119165.MD.gz.
#
# 2024-06-21 18:36:38.008672 caching file sra.recount_pred.SRP119165.MD.gz.
#
# 2024-06-21 18:36:38.194296 downloading and reading the feature information.
#
# 2024-06-21 18:36:38.4568 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:36:38.870549 downloading and reading the counts: 6 samples across 63856 features.
#
# 2024-06-21 18:36:39.223624 caching file sra.gene_sums.SRP119165.G026.gz.
#
# 2024-06-21 18:36:39.457314 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:36:39.515942 downloading and reading the metadata.
#
# 2024-06-21 18:36:39.8929 caching file sra.sra.SRP133965.MD.gz.
#
# 2024-06-21 18:36:40.40811 caching file sra.recount_project.SRP133965.MD.gz.
#
# 2024-06-21 18:36:40.932942 caching file sra.recount_qc.SRP133965.MD.gz.
#
# 2024-06-21 18:36:41.444739 caching file sra.recount_seq_qc.SRP133965.MD.gz.
#
# 2024-06-21 18:36:41.982121 caching file sra.recount_pred.SRP133965.MD.gz.
#
# 2024-06-21 18:36:42.160262 downloading and reading the feature information.
#
# 2024-06-21 18:36:42.441585 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:36:42.830494 downloading and reading the counts: 12 samples across 63856 features.
#
# 2024-06-21 18:36:43.174165 caching file sra.gene_sums.SRP133965.G026.gz.
#
# 2024-06-21 18:36:43.404496 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:36:43.516609 downloading and reading the metadata.
#
# 2024-06-21 18:36:43.886006 caching file sra.sra.SRP096765.MD.gz.
#
# 2024-06-21 18:36:44.386557 caching file sra.recount_project.SRP096765.MD.gz.
#
# 2024-06-21 18:36:44.884595 caching file sra.recount_qc.SRP096765.MD.gz.
#
# 2024-06-21 18:36:45.409034 caching file sra.recount_seq_qc.SRP096765.MD.gz.
#
# 2024-06-21 18:36:45.92311 caching file sra.recount_pred.SRP096765.MD.gz.
#
# 2024-06-21 18:36:46.076962 downloading and reading the feature information.
#
# 2024-06-21 18:36:46.326209 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:36:46.693363 downloading and reading the counts: 7 samples across 63856 features.
#
# 2024-06-21 18:36:47.06387 caching file sra.gene_sums.SRP096765.G026.gz.
#
# 2024-06-21 18:36:47.265576 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:36:47.323905 downloading and reading the metadata.
#
# 2024-06-21 18:36:47.686967 caching file sra.sra.SRP124965.MD.gz.
#
# 2024-06-21 18:36:48.182875 caching file sra.recount_project.SRP124965.MD.gz.
#
# 2024-06-21 18:36:48.698054 caching file sra.recount_qc.SRP124965.MD.gz.
#
# 2024-06-21 18:36:49.179299 caching file sra.recount_seq_qc.SRP124965.MD.gz.
#
# 2024-06-21 18:36:49.696202 caching file sra.recount_pred.SRP124965.MD.gz.
#
# 2024-06-21 18:36:49.866872 downloading and reading the feature information.
#
# 2024-06-21 18:36:50.139555 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:36:50.528641 downloading and reading the counts: 12 samples across 63856 features.
#
# 2024-06-21 18:36:50.778756 caching file sra.gene_sums.SRP124965.G026.gz.
#
# 2024-06-21 18:36:51.005261 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:36:51.07355 downloading and reading the metadata.
#
# 2024-06-21 18:36:51.439474 caching file sra.sra.SRP189165.MD.gz.
#
# 2024-06-21 18:36:51.954987 caching file sra.recount_project.SRP189165.MD.gz.
#
# 2024-06-21 18:36:52.481091 caching file sra.recount_qc.SRP189165.MD.gz.
#
# 2024-06-21 18:36:53.010005 caching file sra.recount_seq_qc.SRP189165.MD.gz.
#
# 2024-06-21 18:36:53.511772 caching file sra.recount_pred.SRP189165.MD.gz.
#
# 2024-06-21 18:36:53.688703 downloading and reading the feature information.
#
# 2024-06-21 18:36:53.954928 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:36:54.354915 downloading and reading the counts: 15 samples across 63856 features.
#
# 2024-06-21 18:36:54.71335 caching file sra.gene_sums.SRP189165.G026.gz.
#
# 2024-06-21 18:36:54.999302 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:36:55.07372 downloading and reading the metadata.
#
# 2024-06-21 18:36:55.496678 caching file sra.sra.SRP050365.MD.gz.
#
# 2024-06-21 18:36:55.980694 caching file sra.recount_project.SRP050365.MD.gz.
#
# 2024-06-21 18:36:56.459303 caching file sra.recount_qc.SRP050365.MD.gz.
#
# 2024-06-21 18:36:56.867619 caching file sra.recount_seq_qc.SRP050365.MD.gz.
#
# 2024-06-21 18:36:57.346911 caching file sra.recount_pred.SRP050365.MD.gz.
#
# 2024-06-21 18:36:57.498798 downloading and reading the feature information.
#
# 2024-06-21 18:36:57.75791 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:36:58.127208 downloading and reading the counts: 10 samples across 63856 features.
#
# 2024-06-21 18:36:58.406235 caching file sra.gene_sums.SRP050365.G026.gz.
#
# 2024-06-21 18:36:58.613901 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:36:58.676436 downloading and reading the metadata.
#
# 2024-06-21 18:36:59.031627 caching file sra.sra.SRP123065.MD.gz.
#
# 2024-06-21 18:36:59.548374 caching file sra.recount_project.SRP123065.MD.gz.
#
# 2024-06-21 18:37:00.043263 caching file sra.recount_qc.SRP123065.MD.gz.
#
# 2024-06-21 18:37:00.455078 caching file sra.recount_seq_qc.SRP123065.MD.gz.
#
# 2024-06-21 18:37:01.007182 caching file sra.recount_pred.SRP123065.MD.gz.
#
# 2024-06-21 18:37:01.168023 downloading and reading the feature information.
#
# 2024-06-21 18:37:01.417957 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:37:01.778447 downloading and reading the counts: 41 samples across 63856 features.
#
# 2024-06-21 18:37:02.055887 caching file sra.gene_sums.SRP123065.G026.gz.
#
# 2024-06-21 18:37:02.30548 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:37:02.457445 downloading and reading the metadata.
#
# 2024-06-21 18:37:02.76807 caching file sra.sra.SRP162465.MD.gz.
#
# 2024-06-21 18:37:03.285362 caching file sra.recount_project.SRP162465.MD.gz.
#
# 2024-06-21 18:37:03.707046 caching file sra.recount_qc.SRP162465.MD.gz.
#
# 2024-06-21 18:37:04.117118 caching file sra.recount_seq_qc.SRP162465.MD.gz.
#
# 2024-06-21 18:37:04.52774 caching file sra.recount_pred.SRP162465.MD.gz.
#
# 2024-06-21 18:37:04.687825 downloading and reading the feature information.
#
# 2024-06-21 18:37:04.96169 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:37:05.368508 downloading and reading the counts: 8 samples across 63856 features.
#
# 2024-06-21 18:37:05.71762 caching file sra.gene_sums.SRP162465.G026.gz.
#
# 2024-06-21 18:37:05.907007 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:37:05.964942 downloading and reading the metadata.
#
# 2024-06-21 18:37:06.240593 caching file sra.sra.SRP178865.MD.gz.
#
# 2024-06-21 18:37:06.746085 caching file sra.recount_project.SRP178865.MD.gz.
#
# 2024-06-21 18:37:07.151705 caching file sra.recount_qc.SRP178865.MD.gz.
#
# 2024-06-21 18:37:07.687758 caching file sra.recount_seq_qc.SRP178865.MD.gz.
#
# 2024-06-21 18:37:08.199652 caching file sra.recount_pred.SRP178865.MD.gz.
#
# 2024-06-21 18:37:08.349165 downloading and reading the feature information.
#
# 2024-06-21 18:37:08.612449 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:37:08.966289 downloading and reading the counts: 24 samples across 63856 features.
#
# 2024-06-21 18:37:09.229909 caching file sra.gene_sums.SRP178865.G026.gz.
#
# 2024-06-21 18:37:09.455658 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:37:09.546086 downloading and reading the metadata.
#
# 2024-06-21 18:37:09.862165 caching file sra.sra.SRP032165.MD.gz.
#
# 2024-06-21 18:37:10.276578 caching file sra.recount_project.SRP032165.MD.gz.
#
# 2024-06-21 18:37:10.699315 caching file sra.recount_qc.SRP032165.MD.gz.
#
# 2024-06-21 18:37:11.250479 caching file sra.recount_seq_qc.SRP032165.MD.gz.
#
# 2024-06-21 18:37:11.668319 caching file sra.recount_pred.SRP032165.MD.gz.
#
# 2024-06-21 18:37:11.824888 downloading and reading the feature information.
#
# 2024-06-21 18:37:12.251025 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:37:12.63601 downloading and reading the counts: 24 samples across 63856 features.
#
# 2024-06-21 18:37:12.973778 caching file sra.gene_sums.SRP032165.G026.gz.
#
# 2024-06-21 18:37:13.210886 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:37:13.334333 downloading and reading the metadata.
#
# 2024-06-21 18:37:13.617189 caching file sra.sra.SRP125965.MD.gz.
#
# 2024-06-21 18:37:14.199311 caching file sra.recount_project.SRP125965.MD.gz.
#
# 2024-06-21 18:37:14.742218 caching file sra.recount_qc.SRP125965.MD.gz.
#
# 2024-06-21 18:37:15.297102 caching file sra.recount_seq_qc.SRP125965.MD.gz.
#
# 2024-06-21 18:37:15.852467 caching file sra.recount_pred.SRP125965.MD.gz.
#
# 2024-06-21 18:37:15.99871 downloading and reading the feature information.
#
# 2024-06-21 18:37:16.272245 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:37:16.620188 downloading and reading the counts: 72 samples across 63856 features.
#
# 2024-06-21 18:37:16.9124 caching file sra.gene_sums.SRP125965.G026.gz.
#
# 2024-06-21 18:37:17.184644 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:37:17.444363 downloading and reading the metadata.
#
# 2024-06-21 18:37:17.799231 caching file sra.sra.SRP120165.MD.gz.
#
# 2024-06-21 18:37:18.265281 caching file sra.recount_project.SRP120165.MD.gz.
#
# 2024-06-21 18:37:18.794013 caching file sra.recount_qc.SRP120165.MD.gz.
#
# 2024-06-21 18:37:19.28704 caching file sra.recount_seq_qc.SRP120165.MD.gz.
#
# 2024-06-21 18:37:19.689488 caching file sra.recount_pred.SRP120165.MD.gz.
#
# 2024-06-21 18:37:19.839517 downloading and reading the feature information.
#
# 2024-06-21 18:37:20.098232 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:37:20.456925 downloading and reading the counts: 18 samples across 63856 features.
#
# 2024-06-21 18:37:20.733668 caching file sra.gene_sums.SRP120165.G026.gz.
#
# 2024-06-21 18:37:20.999797 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:37:21.079177 downloading and reading the metadata.
#
# 2024-06-21 18:37:21.442879 caching file sra.sra.SRP044265.MD.gz.
#
# 2024-06-21 18:37:21.938957 caching file sra.recount_project.SRP044265.MD.gz.
#
# 2024-06-21 18:37:22.318473 caching file sra.recount_qc.SRP044265.MD.gz.
#
# 2024-06-21 18:37:22.747164 caching file sra.recount_seq_qc.SRP044265.MD.gz.
#
# 2024-06-21 18:37:23.143391 caching file sra.recount_pred.SRP044265.MD.gz.
#
# 2024-06-21 18:37:23.290583 downloading and reading the feature information.
#
# 2024-06-21 18:37:23.571027 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:37:23.924661 downloading and reading the counts: 6 samples across 63856 features.
#
# 2024-06-21 18:37:24.280366 caching file sra.gene_sums.SRP044265.G026.gz.
#
# 2024-06-21 18:37:24.471454 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:37:24.524928 downloading and reading the metadata.
#
# 2024-06-21 18:37:24.889455 caching file sra.sra.SRP014565.MD.gz.
#
# 2024-06-21 18:37:25.40538 caching file sra.recount_project.SRP014565.MD.gz.
#
# 2024-06-21 18:37:25.819482 caching file sra.recount_qc.SRP014565.MD.gz.
#
# 2024-06-21 18:37:26.383336 caching file sra.recount_seq_qc.SRP014565.MD.gz.
#
# 2024-06-21 18:37:27.474725 caching file sra.recount_pred.SRP014565.MD.gz.
#
# 2024-06-21 18:37:27.62917 downloading and reading the feature information.
#
# 2024-06-21 18:37:27.890103 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:37:28.261744 downloading and reading the counts: 1 sample across 63856 features.
#
# 2024-06-21 18:37:28.60917 caching file sra.gene_sums.SRP014565.G026.gz.
#
# 2024-06-21 18:37:28.799571 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:37:28.844182 downloading and reading the metadata.
#
# 2024-06-21 18:37:29.1326 caching file sra.sra.SRP057065.MD.gz.
#
# 2024-06-21 18:37:29.549126 caching file sra.recount_project.SRP057065.MD.gz.
#
# 2024-06-21 18:37:29.974318 caching file sra.recount_qc.SRP057065.MD.gz.
#
# 2024-06-21 18:37:30.407141 caching file sra.recount_seq_qc.SRP057065.MD.gz.
#
# 2024-06-21 18:37:30.912801 caching file sra.recount_pred.SRP057065.MD.gz.
#
# 2024-06-21 18:37:31.077773 downloading and reading the feature information.
#
# 2024-06-21 18:37:31.362132 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:37:31.753846 downloading and reading the counts: 51 samples across 63856 features.
#
# 2024-06-21 18:37:32.120559 caching file sra.gene_sums.SRP057065.G026.gz.
#
# 2024-06-21 18:37:32.37379 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:37:32.56389 downloading and reading the metadata.
#
# 2024-06-21 18:37:32.87423 caching file sra.sra.SRP117665.MD.gz.
#
# 2024-06-21 18:37:33.365981 caching file sra.recount_project.SRP117665.MD.gz.
#
# 2024-06-21 18:37:33.820516 caching file sra.recount_qc.SRP117665.MD.gz.
#
# 2024-06-21 18:37:34.320433 caching file sra.recount_seq_qc.SRP117665.MD.gz.
#
# 2024-06-21 18:37:34.80433 caching file sra.recount_pred.SRP117665.MD.gz.
#
# 2024-06-21 18:37:34.955267 downloading and reading the feature information.
#
# 2024-06-21 18:37:35.212948 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:37:35.573016 downloading and reading the counts: 9 samples across 63856 features.
#
# 2024-06-21 18:37:35.831043 caching file sra.gene_sums.SRP117665.G026.gz.
#
# 2024-06-21 18:37:36.03206 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:37:36.093268 downloading and reading the metadata.
#
# 2024-06-21 18:37:36.377168 caching file sra.sra.SRP049465.MD.gz.
#
# 2024-06-21 18:37:36.805461 caching file sra.recount_project.SRP049465.MD.gz.
#
# 2024-06-21 18:37:37.253878 caching file sra.recount_qc.SRP049465.MD.gz.
#
# 2024-06-21 18:37:37.758598 caching file sra.recount_seq_qc.SRP049465.MD.gz.
#
# 2024-06-21 18:37:38.162762 caching file sra.recount_pred.SRP049465.MD.gz.
#
# 2024-06-21 18:37:38.3092 downloading and reading the feature information.
#
# 2024-06-21 18:37:38.582628 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:37:38.936547 downloading and reading the counts: 4 samples across 63856 features.
#
# 2024-06-21 18:37:39.323044 caching file sra.gene_sums.SRP049465.G026.gz.
#
# 2024-06-21 18:37:39.510426 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:37:39.559823 downloading and reading the metadata.
#
# 2024-06-21 18:37:39.818048 caching file sra.sra.SRP007665.MD.gz.
#
# 2024-06-21 18:37:40.272022 caching file sra.recount_project.SRP007665.MD.gz.
#
# 2024-06-21 18:37:40.760646 caching file sra.recount_qc.SRP007665.MD.gz.
#
# 2024-06-21 18:37:41.177598 caching file sra.recount_seq_qc.SRP007665.MD.gz.
#
# 2024-06-21 18:37:41.573462 caching file sra.recount_pred.SRP007665.MD.gz.
#
# 2024-06-21 18:37:41.727423 downloading and reading the feature information.
#
# 2024-06-21 18:37:41.984886 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:37:42.353996 downloading and reading the counts: 1 sample across 63856 features.
#
# 2024-06-21 18:37:42.729635 caching file sra.gene_sums.SRP007665.G026.gz.
#
# 2024-06-21 18:37:42.922767 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:37:42.966972 downloading and reading the metadata.
#
# 2024-06-21 18:37:43.240442 caching file sra.sra.SRP124265.MD.gz.
#
# 2024-06-21 18:37:43.730006 caching file sra.recount_project.SRP124265.MD.gz.
#
# 2024-06-21 18:37:44.255505 caching file sra.recount_qc.SRP124265.MD.gz.
#
# 2024-06-21 18:37:44.676035 caching file sra.recount_seq_qc.SRP124265.MD.gz.
#
# 2024-06-21 18:37:45.101646 caching file sra.recount_pred.SRP124265.MD.gz.
#
# 2024-06-21 18:37:45.266895 downloading and reading the feature information.
#
# 2024-06-21 18:37:45.543576 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:37:45.919228 downloading and reading the counts: 2 samples across 63856 features.
#
# 2024-06-21 18:37:46.213942 caching file sra.gene_sums.SRP124265.G026.gz.
#
# 2024-06-21 18:37:46.46013 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:37:46.506448 downloading and reading the metadata.
#
# 2024-06-21 18:37:46.800745 caching file sra.sra.SRP187765.MD.gz.
#
# 2024-06-21 18:37:47.228264 caching file sra.recount_project.SRP187765.MD.gz.
#
# 2024-06-21 18:37:47.622751 caching file sra.recount_qc.SRP187765.MD.gz.
#
# 2024-06-21 18:37:48.103662 caching file sra.recount_seq_qc.SRP187765.MD.gz.
#
# 2024-06-21 18:37:48.517677 caching file sra.recount_pred.SRP187765.MD.gz.
#
# 2024-06-21 18:37:48.666483 downloading and reading the feature information.
#
# 2024-06-21 18:37:48.937517 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:37:49.296871 downloading and reading the counts: 14 samples across 63856 features.
#
# 2024-06-21 18:37:49.580479 caching file sra.gene_sums.SRP187765.G026.gz.
#
# 2024-06-21 18:37:49.787253 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:37:49.854449 downloading and reading the metadata.
#
# 2024-06-21 18:37:50.134523 caching file sra.sra.SRP157965.MD.gz.
#
# 2024-06-21 18:37:50.629202 caching file sra.recount_project.SRP157965.MD.gz.
#
# 2024-06-21 18:37:51.039019 caching file sra.recount_qc.SRP157965.MD.gz.
#
# 2024-06-21 18:37:51.468925 caching file sra.recount_seq_qc.SRP157965.MD.gz.
#
# 2024-06-21 18:37:51.902099 caching file sra.recount_pred.SRP157965.MD.gz.
#
# 2024-06-21 18:37:52.059692 downloading and reading the feature information.
#
# 2024-06-21 18:37:52.321793 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:37:52.684839 downloading and reading the counts: 63 samples across 63856 features.
#
# 2024-06-21 18:37:53.044874 caching file sra.gene_sums.SRP157965.G026.gz.
#
# 2024-06-21 18:37:53.34702 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:37:53.592487 downloading and reading the metadata.
#
# 2024-06-21 18:37:53.963702 caching file sra.sra.SRP150065.MD.gz.
#
# 2024-06-21 18:37:54.491962 caching file sra.recount_project.SRP150065.MD.gz.
#
# 2024-06-21 18:37:54.970942 caching file sra.recount_qc.SRP150065.MD.gz.
#
# 2024-06-21 18:37:55.384861 caching file sra.recount_seq_qc.SRP150065.MD.gz.
#
# 2024-06-21 18:37:55.857577 caching file sra.recount_pred.SRP150065.MD.gz.
#
# 2024-06-21 18:37:56.005661 downloading and reading the feature information.
#
# 2024-06-21 18:37:56.307353 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:37:56.661155 downloading and reading the counts: 18 samples across 63856 features.
#
# 2024-06-21 18:37:56.941935 caching file sra.gene_sums.SRP150065.G026.gz.
#
# 2024-06-21 18:37:58.034171 constructing the RangedSummarizedExperiment (rse) object.
#
# Warning message:
# “One or more chunk dimensions exceeded the maximum for the dataset.
# These have been automatically set to the maximum.
# The new chunk dimensions are: c(40716,661)”
# You created a large dataset with compression and chunking.
# The chunk size is equal to the dataset dimensions.
# If you want to read subsets of the dataset, you should testsmaller chunk sizes to improve read times.
#
# 2024-06-21 18:37:58.141702 downloading and reading the metadata.
#
# 2024-06-21 18:37:58.411086 caching file sra.sra.SRP107565.MD.gz.
#
# 2024-06-21 18:37:58.85923 caching file sra.recount_project.SRP107565.MD.gz.
#
# 2024-06-21 18:37:59.252154 caching file sra.recount_qc.SRP107565.MD.gz.
#
# 2024-06-21 18:37:59.687052 caching file sra.recount_seq_qc.SRP107565.MD.gz.
#
# Warning message:
# “The 'url' <http://duffel.rail.bio/recount3/human/data_sources/sra/metadata/65/SRP107565/sra.recount_pred.SRP107565.MD.gz> does not exist or is not available.”
# 2024-06-21 18:38:00.032157 downloading and reading the feature information.
#
# 2024-06-21 18:38:00.290205 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:38:00.639812 downloading and reading the counts: 216 samples across 63856 features.
#
# 2024-06-21 18:38:00.905706 caching file sra.gene_sums.SRP107565.G026.gz.
#
# 2024-06-21 18:38:01.414804 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:38:08.077754 downloading and reading the metadata.
#
# 2024-06-21 18:38:08.469426 caching file sra.sra.SRP149665.MD.gz.
#
# 2024-06-21 18:38:08.878872 caching file sra.recount_project.SRP149665.MD.gz.
#
# 2024-06-21 18:38:09.295157 caching file sra.recount_qc.SRP149665.MD.gz.
#
# 2024-06-21 18:38:09.723445 caching file sra.recount_seq_qc.SRP149665.MD.gz.
#
# 2024-06-21 18:38:10.124664 caching file sra.recount_pred.SRP149665.MD.gz.
#
# 2024-06-21 18:38:10.276162 downloading and reading the feature information.
#
# 2024-06-21 18:38:10.566353 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:38:10.922303 downloading and reading the counts: 4 samples across 63856 features.
#
# 2024-06-21 18:38:11.204623 caching file sra.gene_sums.SRP149665.G026.gz.
#
# 2024-06-21 18:38:11.396036 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:38:17.48128 downloading and reading the metadata.
#
# 2024-06-21 18:38:17.920609 caching file sra.sra.SRP017465.MD.gz.
#
# 2024-06-21 18:38:18.387332 caching file sra.recount_project.SRP017465.MD.gz.
#
# 2024-06-21 18:38:18.831392 caching file sra.recount_qc.SRP017465.MD.gz.
#
# 2024-06-21 18:38:19.331409 caching file sra.recount_seq_qc.SRP017465.MD.gz.
#
# 2024-06-21 18:38:19.739799 caching file sra.recount_pred.SRP017465.MD.gz.
#
# 2024-06-21 18:38:19.896232 downloading and reading the feature information.
#
# 2024-06-21 18:38:20.161714 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:38:20.521082 downloading and reading the counts: 23 samples across 63856 features.
#
# 2024-06-21 18:38:20.791911 caching file sra.gene_sums.SRP017465.G026.gz.
#
# 2024-06-21 18:38:21.024136 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:38:27.657375 downloading and reading the metadata.
#
# 2024-06-21 18:38:28.067914 caching file sra.sra.SRP119165.MD.gz.
#
# 2024-06-21 18:38:28.58178 caching file sra.recount_project.SRP119165.MD.gz.
#
# 2024-06-21 18:38:29.010383 caching file sra.recount_qc.SRP119165.MD.gz.
#
# 2024-06-21 18:38:29.443443 caching file sra.recount_seq_qc.SRP119165.MD.gz.
#
# 2024-06-21 18:38:29.867441 caching file sra.recount_pred.SRP119165.MD.gz.
#
# 2024-06-21 18:38:30.028532 downloading and reading the feature information.
#
# 2024-06-21 18:38:30.303217 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:38:30.669788 downloading and reading the counts: 6 samples across 63856 features.
#
# 2024-06-21 18:38:30.946211 caching file sra.gene_sums.SRP119165.G026.gz.
#
# 2024-06-21 18:38:31.15481 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:38:37.893954 downloading and reading the metadata.
#
# 2024-06-21 18:38:38.29838 caching file sra.sra.SRP133965.MD.gz.
#
# 2024-06-21 18:38:38.727116 caching file sra.recount_project.SRP133965.MD.gz.
#
# 2024-06-21 18:38:39.144796 caching file sra.recount_qc.SRP133965.MD.gz.
#
# 2024-06-21 18:38:39.565854 caching file sra.recount_seq_qc.SRP133965.MD.gz.
#
# 2024-06-21 18:38:39.989271 caching file sra.recount_pred.SRP133965.MD.gz.
#
# 2024-06-21 18:38:40.14809 downloading and reading the feature information.
#
# 2024-06-21 18:38:40.42932 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:38:40.801342 downloading and reading the counts: 12 samples across 63856 features.
#
# 2024-06-21 18:38:41.115855 caching file sra.gene_sums.SRP133965.G026.gz.
#
# 2024-06-21 18:38:41.330625 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:38:48.287505 downloading and reading the metadata.
#
# 2024-06-21 18:38:48.692106 caching file sra.sra.SRP096765.MD.gz.
#
# 2024-06-21 18:38:49.12824 caching file sra.recount_project.SRP096765.MD.gz.
#
# 2024-06-21 18:38:49.581819 caching file sra.recount_qc.SRP096765.MD.gz.
#
# 2024-06-21 18:38:49.992772 caching file sra.recount_seq_qc.SRP096765.MD.gz.
#
# 2024-06-21 18:38:50.469653 caching file sra.recount_pred.SRP096765.MD.gz.
#
# 2024-06-21 18:38:50.626562 downloading and reading the feature information.
#
# 2024-06-21 18:38:50.954509 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:38:51.328792 downloading and reading the counts: 7 samples across 63856 features.
#
# 2024-06-21 18:38:51.617684 caching file sra.gene_sums.SRP096765.G026.gz.
#
# 2024-06-21 18:38:51.82849 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:38:58.977317 downloading and reading the metadata.
#
# 2024-06-21 18:38:59.383116 caching file sra.sra.SRP124965.MD.gz.
#
# 2024-06-21 18:38:59.884638 caching file sra.recount_project.SRP124965.MD.gz.
#
# 2024-06-21 18:39:00.308187 caching file sra.recount_qc.SRP124965.MD.gz.
#
# 2024-06-21 18:39:00.737246 caching file sra.recount_seq_qc.SRP124965.MD.gz.
#
# 2024-06-21 18:39:01.234097 caching file sra.recount_pred.SRP124965.MD.gz.
#
# 2024-06-21 18:39:01.408215 downloading and reading the feature information.
#
# 2024-06-21 18:39:01.692954 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:39:02.079256 downloading and reading the counts: 12 samples across 63856 features.
#
# 2024-06-21 18:39:02.335819 caching file sra.gene_sums.SRP124965.G026.gz.
#
# 2024-06-21 18:39:02.599752 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:39:09.935171 downloading and reading the metadata.
#
# 2024-06-21 18:39:10.346906 caching file sra.sra.SRP189165.MD.gz.
#
# 2024-06-21 18:39:10.74197 caching file sra.recount_project.SRP189165.MD.gz.
#
# 2024-06-21 18:39:11.160105 caching file sra.recount_qc.SRP189165.MD.gz.
#
# 2024-06-21 18:39:11.60664 caching file sra.recount_seq_qc.SRP189165.MD.gz.
#
# 2024-06-21 18:39:12.043344 caching file sra.recount_pred.SRP189165.MD.gz.
#
# 2024-06-21 18:39:12.197248 downloading and reading the feature information.
#
# 2024-06-21 18:39:12.459056 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:39:12.823769 downloading and reading the counts: 15 samples across 63856 features.
#
# 2024-06-21 18:39:13.109848 caching file sra.gene_sums.SRP189165.G026.gz.
#
# 2024-06-21 18:39:13.33017 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:39:20.968421 downloading and reading the metadata.
#
# 2024-06-21 18:39:21.480942 caching file sra.sra.SRP050365.MD.gz.
#
# 2024-06-21 18:39:21.895416 caching file sra.recount_project.SRP050365.MD.gz.
#
# 2024-06-21 18:39:22.276202 caching file sra.recount_qc.SRP050365.MD.gz.
#
# 2024-06-21 18:39:22.697799 caching file sra.recount_seq_qc.SRP050365.MD.gz.
#
# 2024-06-21 18:39:23.108479 caching file sra.recount_pred.SRP050365.MD.gz.
#
# 2024-06-21 18:39:23.263658 downloading and reading the feature information.
#
# 2024-06-21 18:39:23.560332 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:39:23.92715 downloading and reading the counts: 10 samples across 63856 features.
#
# 2024-06-21 18:39:24.322084 caching file sra.gene_sums.SRP050365.G026.gz.
#
# 2024-06-21 18:39:24.543687 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:39:32.305403 downloading and reading the metadata.
#
# 2024-06-21 18:39:32.699983 caching file sra.sra.SRP123065.MD.gz.
#
# 2024-06-21 18:39:33.140871 caching file sra.recount_project.SRP123065.MD.gz.
#
# 2024-06-21 18:39:33.596643 caching file sra.recount_qc.SRP123065.MD.gz.
#
# 2024-06-21 18:39:34.015609 caching file sra.recount_seq_qc.SRP123065.MD.gz.
#
# 2024-06-21 18:39:34.433122 caching file sra.recount_pred.SRP123065.MD.gz.
#
# 2024-06-21 18:39:34.638477 downloading and reading the feature information.
#
# 2024-06-21 18:39:34.906952 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:39:35.263425 downloading and reading the counts: 41 samples across 63856 features.
#
# 2024-06-21 18:39:35.518029 caching file sra.gene_sums.SRP123065.G026.gz.
#
# 2024-06-21 18:39:35.751694 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:39:44.161937 downloading and reading the metadata.
#
# 2024-06-21 18:39:44.536075 caching file sra.sra.SRP162465.MD.gz.
#
# 2024-06-21 18:39:44.938252 caching file sra.recount_project.SRP162465.MD.gz.
#
# 2024-06-21 18:39:45.370901 caching file sra.recount_qc.SRP162465.MD.gz.
#
# 2024-06-21 18:39:45.756764 caching file sra.recount_seq_qc.SRP162465.MD.gz.
#
# 2024-06-21 18:39:46.200788 caching file sra.recount_pred.SRP162465.MD.gz.
#
# 2024-06-21 18:39:46.348898 downloading and reading the feature information.
#
# 2024-06-21 18:39:46.623405 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:39:46.979864 downloading and reading the counts: 8 samples across 63856 features.
#
# 2024-06-21 18:39:47.282887 caching file sra.gene_sums.SRP162465.G026.gz.
#
# 2024-06-21 18:39:47.482175 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:39:55.898175 downloading and reading the metadata.
#
# 2024-06-21 18:39:56.289371 caching file sra.sra.SRP178865.MD.gz.
#
# 2024-06-21 18:39:56.789713 caching file sra.recount_project.SRP178865.MD.gz.
#
# 2024-06-21 18:39:57.214883 caching file sra.recount_qc.SRP178865.MD.gz.
#
# 2024-06-21 18:39:57.627235 caching file sra.recount_seq_qc.SRP178865.MD.gz.
#
# 2024-06-21 18:39:58.085088 caching file sra.recount_pred.SRP178865.MD.gz.
#
# 2024-06-21 18:39:58.247967 downloading and reading the feature information.
#
# 2024-06-21 18:39:58.539099 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:39:58.912783 downloading and reading the counts: 24 samples across 63856 features.
#
# 2024-06-21 18:39:59.176268 caching file sra.gene_sums.SRP178865.G026.gz.
#
# 2024-06-21 18:39:59.428915 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:40:08.45494 downloading and reading the metadata.
#
# 2024-06-21 18:40:08.857842 caching file sra.sra.SRP032165.MD.gz.
#
# 2024-06-21 18:40:09.269547 caching file sra.recount_project.SRP032165.MD.gz.
#
# 2024-06-21 18:40:09.668271 caching file sra.recount_qc.SRP032165.MD.gz.
#
# 2024-06-21 18:40:10.082039 caching file sra.recount_seq_qc.SRP032165.MD.gz.
#
# 2024-06-21 18:40:10.502632 caching file sra.recount_pred.SRP032165.MD.gz.
#
# 2024-06-21 18:40:10.654668 downloading and reading the feature information.
#
# 2024-06-21 18:40:10.920064 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:40:11.285914 downloading and reading the counts: 24 samples across 63856 features.
#
# 2024-06-21 18:40:11.541933 caching file sra.gene_sums.SRP032165.G026.gz.
#
# 2024-06-21 18:40:11.762143 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:40:21.069034 downloading and reading the metadata.
#
# 2024-06-21 18:40:21.502665 caching file sra.sra.SRP125965.MD.gz.
#
# 2024-06-21 18:40:21.948799 caching file sra.recount_project.SRP125965.MD.gz.
#
# 2024-06-21 18:40:22.348568 caching file sra.recount_qc.SRP125965.MD.gz.
#
# 2024-06-21 18:40:22.770928 caching file sra.recount_seq_qc.SRP125965.MD.gz.
#
# 2024-06-21 18:40:23.168104 caching file sra.recount_pred.SRP125965.MD.gz.
#
# 2024-06-21 18:40:23.326469 downloading and reading the feature information.
#
# 2024-06-21 18:40:23.586956 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:40:23.95497 downloading and reading the counts: 72 samples across 63856 features.
#
# 2024-06-21 18:40:24.248051 caching file sra.gene_sums.SRP125965.G026.gz.
#
# 2024-06-21 18:40:24.536129 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:40:35.50887 downloading and reading the metadata.
#
# 2024-06-21 18:40:35.883825 caching file sra.sra.SRP120165.MD.gz.
#
# 2024-06-21 18:40:36.31193 caching file sra.recount_project.SRP120165.MD.gz.
#
# 2024-06-21 18:40:36.81801 caching file sra.recount_qc.SRP120165.MD.gz.
#
# 2024-06-21 18:40:37.329168 caching file sra.recount_seq_qc.SRP120165.MD.gz.
#
# 2024-06-21 18:40:37.75675 caching file sra.recount_pred.SRP120165.MD.gz.
#
# 2024-06-21 18:40:37.906316 downloading and reading the feature information.
#
# 2024-06-21 18:40:38.182501 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:40:38.539543 downloading and reading the counts: 18 samples across 63856 features.
#
# 2024-06-21 18:40:38.831892 caching file sra.gene_sums.SRP120165.G026.gz.
#
# 2024-06-21 18:40:39.045613 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:40:49.915303 downloading and reading the metadata.
#
# 2024-06-21 18:40:50.331058 caching file sra.sra.SRP044265.MD.gz.
#
# 2024-06-21 18:40:50.792272 caching file sra.recount_project.SRP044265.MD.gz.
#
# 2024-06-21 18:40:51.242612 caching file sra.recount_qc.SRP044265.MD.gz.
#
# 2024-06-21 18:40:51.679455 caching file sra.recount_seq_qc.SRP044265.MD.gz.
#
# 2024-06-21 18:40:52.080806 caching file sra.recount_pred.SRP044265.MD.gz.
#
# 2024-06-21 18:40:52.242687 downloading and reading the feature information.
#
# 2024-06-21 18:40:52.507221 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:40:52.869461 downloading and reading the counts: 6 samples across 63856 features.
#
# 2024-06-21 18:40:53.16608 caching file sra.gene_sums.SRP044265.G026.gz.
#
# 2024-06-21 18:40:53.368999 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:41:04.352417 downloading and reading the metadata.
#
# 2024-06-21 18:41:04.770205 caching file sra.sra.SRP014565.MD.gz.
#
# 2024-06-21 18:41:05.205786 caching file sra.recount_project.SRP014565.MD.gz.
#
# 2024-06-21 18:41:05.746079 caching file sra.recount_qc.SRP014565.MD.gz.
#
# 2024-06-21 18:41:06.203151 caching file sra.recount_seq_qc.SRP014565.MD.gz.
#
# 2024-06-21 18:41:06.605717 caching file sra.recount_pred.SRP014565.MD.gz.
#
# 2024-06-21 18:41:06.768644 downloading and reading the feature information.
#
# 2024-06-21 18:41:07.042286 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:41:07.4297 downloading and reading the counts: 1 sample across 63856 features.
#
# 2024-06-21 18:41:07.714567 caching file sra.gene_sums.SRP014565.G026.gz.
#
# 2024-06-21 18:41:07.916251 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:41:18.880796 downloading and reading the metadata.
#
# 2024-06-21 18:41:19.286688 caching file sra.sra.SRP057065.MD.gz.
#
# 2024-06-21 18:41:19.780264 caching file sra.recount_project.SRP057065.MD.gz.
#
# 2024-06-21 18:41:20.218143 caching file sra.recount_qc.SRP057065.MD.gz.
#
# 2024-06-21 18:41:20.642636 caching file sra.recount_seq_qc.SRP057065.MD.gz.
#
# 2024-06-21 18:41:21.027388 caching file sra.recount_pred.SRP057065.MD.gz.
#
# 2024-06-21 18:41:21.180153 downloading and reading the feature information.
#
# 2024-06-21 18:41:21.463201 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:41:21.825102 downloading and reading the counts: 51 samples across 63856 features.
#
# 2024-06-21 18:41:22.102205 caching file sra.gene_sums.SRP057065.G026.gz.
#
# 2024-06-21 18:41:22.361667 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:41:34.681134 downloading and reading the metadata.
#
# 2024-06-21 18:41:35.092953 caching file sra.sra.SRP117665.MD.gz.
#
# 2024-06-21 18:41:35.54514 caching file sra.recount_project.SRP117665.MD.gz.
#
# 2024-06-21 18:41:35.985469 caching file sra.recount_qc.SRP117665.MD.gz.
#
# 2024-06-21 18:41:36.384434 caching file sra.recount_seq_qc.SRP117665.MD.gz.
#
# 2024-06-21 18:41:36.838277 caching file sra.recount_pred.SRP117665.MD.gz.
#
# 2024-06-21 18:41:36.994638 downloading and reading the feature information.
#
# 2024-06-21 18:41:37.261883 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:41:37.65885 downloading and reading the counts: 9 samples across 63856 features.
#
# 2024-06-21 18:41:37.9871 caching file sra.gene_sums.SRP117665.G026.gz.
#
# 2024-06-21 18:41:38.194865 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:41:50.60339 downloading and reading the metadata.
#
# 2024-06-21 18:41:50.996525 caching file sra.sra.SRP049465.MD.gz.
#
# 2024-06-21 18:41:51.405078 caching file sra.recount_project.SRP049465.MD.gz.
#
# 2024-06-21 18:41:51.864972 caching file sra.recount_qc.SRP049465.MD.gz.
#
# 2024-06-21 18:41:52.30285 caching file sra.recount_seq_qc.SRP049465.MD.gz.
#
# 2024-06-21 18:41:52.764633 caching file sra.recount_pred.SRP049465.MD.gz.
#
# 2024-06-21 18:41:52.929029 downloading and reading the feature information.
#
# 2024-06-21 18:41:53.201015 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:41:53.586184 downloading and reading the counts: 4 samples across 63856 features.
#
# 2024-06-21 18:41:53.909697 caching file sra.gene_sums.SRP049465.G026.gz.
#
# 2024-06-21 18:41:54.118679 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:42:06.658198 downloading and reading the metadata.
#
# 2024-06-21 18:42:07.06966 caching file sra.sra.SRP007665.MD.gz.
#
# 2024-06-21 18:42:07.470579 caching file sra.recount_project.SRP007665.MD.gz.
#
# 2024-06-21 18:42:07.864629 caching file sra.recount_qc.SRP007665.MD.gz.
#
# 2024-06-21 18:42:08.28101 caching file sra.recount_seq_qc.SRP007665.MD.gz.
#
# 2024-06-21 18:42:09.006315 caching file sra.recount_pred.SRP007665.MD.gz.
#
# 2024-06-21 18:42:09.152923 downloading and reading the feature information.
#
# 2024-06-21 18:42:09.494331 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:42:09.84926 downloading and reading the counts: 1 sample across 63856 features.
#
# 2024-06-21 18:42:10.114702 caching file sra.gene_sums.SRP007665.G026.gz.
#
# 2024-06-21 18:42:10.301834 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:42:22.780759 downloading and reading the metadata.
#
# 2024-06-21 18:42:23.18117 caching file sra.sra.SRP124265.MD.gz.
#
# 2024-06-21 18:42:23.575253 caching file sra.recount_project.SRP124265.MD.gz.
#
# 2024-06-21 18:42:23.983225 caching file sra.recount_qc.SRP124265.MD.gz.
#
# 2024-06-21 18:42:24.436804 caching file sra.recount_seq_qc.SRP124265.MD.gz.
#
# 2024-06-21 18:42:24.882865 caching file sra.recount_pred.SRP124265.MD.gz.
#
# 2024-06-21 18:42:25.038471 downloading and reading the feature information.
#
# 2024-06-21 18:42:25.29555 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:42:25.66033 downloading and reading the counts: 2 samples across 63856 features.
#
# 2024-06-21 18:42:25.973803 caching file sra.gene_sums.SRP124265.G026.gz.
#
# 2024-06-21 18:42:26.169236 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:42:38.687397 downloading and reading the metadata.
#
# 2024-06-21 18:42:39.118444 caching file sra.sra.SRP187765.MD.gz.
#
# 2024-06-21 18:42:39.550718 caching file sra.recount_project.SRP187765.MD.gz.
#
# 2024-06-21 18:42:39.973338 caching file sra.recount_qc.SRP187765.MD.gz.
#
# 2024-06-21 18:42:40.417251 caching file sra.recount_seq_qc.SRP187765.MD.gz.
#
# 2024-06-21 18:42:40.862285 caching file sra.recount_pred.SRP187765.MD.gz.
#
# 2024-06-21 18:42:41.029025 downloading and reading the feature information.
#
# 2024-06-21 18:42:41.32322 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:42:41.701106 downloading and reading the counts: 14 samples across 63856 features.
#
# 2024-06-21 18:42:41.96826 caching file sra.gene_sums.SRP187765.G026.gz.
#
# 2024-06-21 18:42:42.234277 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:42:55.04805 downloading and reading the metadata.
#
# 2024-06-21 18:42:55.497005 caching file sra.sra.SRP157965.MD.gz.
#
# 2024-06-21 18:42:56.001018 caching file sra.recount_project.SRP157965.MD.gz.
#
# 2024-06-21 18:42:56.405646 caching file sra.recount_qc.SRP157965.MD.gz.
#
# 2024-06-21 18:42:56.81457 caching file sra.recount_seq_qc.SRP157965.MD.gz.
#
# 2024-06-21 18:42:57.226462 caching file sra.recount_pred.SRP157965.MD.gz.
#
# 2024-06-21 18:42:57.379859 downloading and reading the feature information.
#
# 2024-06-21 18:42:57.645922 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:42:58.007853 downloading and reading the counts: 63 samples across 63856 features.
#
# 2024-06-21 18:42:58.297312 caching file sra.gene_sums.SRP157965.G026.gz.
#
# 2024-06-21 18:42:58.599539 constructing the RangedSummarizedExperiment (rse) object.
#
# 2024-06-21 18:43:12.798007 downloading and reading the metadata.
#
# 2024-06-21 18:43:13.190965 caching file sra.sra.SRP150065.MD.gz.
#
# 2024-06-21 18:43:13.622408 caching file sra.recount_project.SRP150065.MD.gz.
#
# 2024-06-21 18:43:14.055552 caching file sra.recount_qc.SRP150065.MD.gz.
#
# 2024-06-21 18:43:14.480011 caching file sra.recount_seq_qc.SRP150065.MD.gz.
#
# 2024-06-21 18:43:14.908976 caching file sra.recount_pred.SRP150065.MD.gz.
#
# 2024-06-21 18:43:15.112423 downloading and reading the feature information.
#
# 2024-06-21 18:43:15.393349 caching file human.gene_sums.G026.gtf.gz.
#
# 2024-06-21 18:43:15.753853 downloading and reading the counts: 18 samples across 63856 features.
#
# 2024-06-21 18:43:16.116228 caching file sra.gene_sums.SRP150065.G026.gz.
#
# 2024-06-21 18:43:16.326878 constructing the RangedSummarizedExperiment (rse) object.

# %%
all_rownames  <- rownames(initial_matrix)
dimnames_rds <- file.path(output_nb_path, "dimnames.RDS")
saveRDS(list(row.names = all_rownames, col.names = all_colnames), file = dimnames_rds)

# %%
recount3_h5 <- file.path(output_nb_path, "recount3_dataset_tpm.h5")
dimnames_rds <- file.path(output_nb_path, "dimnames.RDS")

sce <- DelayedArray(seed = HDF5ArraySeed(filepath = recount3_h5, name = "count"))
dimnamaes <- readRDS(dimnames_rds)
rownames(sce) <- dimnamaes$row.names
colnames(sce) <- dimnamaes$col.names

sce[is.na(sce)] <- 0
sce <- sce[which(DelayedMatrixStats::rowSds(sce) >0),]

sce
# Out:
# <38447 x 661> DelayedMatrix object of type "double":
#          SRR5579425  SRR5579426  SRR5579433 ... SRR7280714 SRR7280715
#   SCYL3  7.60426358  8.21645078  8.64601075   .  6.3227423  5.2750730
#   FIRRM 12.19380568 11.15075743  8.95064922   . 14.5106309 10.7818084
#     FGR  0.00000000  0.00000000  0.00000000   .  0.0000000  0.0785297
#     CFH  0.07174062  0.00000000  0.00000000   .  8.7081807  7.1243656
#   STPG1  1.96629475  1.70422297  1.39559122   .  3.2590608  3.2634849
#     ...           .           .           .   .          .          .
# MIR24-1    4.124663    5.854525    0.000000   .   1.132107   0.000000
#  MIR363    0.000000    0.000000    0.000000   .   0.000000   0.000000
# MIR92A2    0.000000    0.000000    0.000000   .   0.000000   0.000000
# MIR2861    0.000000    0.000000    0.000000   .   0.000000   0.000000
#  MIR223    0.000000    0.000000    0.000000   .   0.000000   0.000000

# %% [markdown]
# # Prepare data for all the models

# %%
all_paths <- PLIER::combinePaths(bloodCellMarkersIRISDMAP, svmMarkers, canonicalPathways, chemgenPathways, oncogenicPathways,
                                 xCell, immunePathways, chr21_pathway)

# %% [markdown]
# Keep all the genes present in RNA-seq matrix adding 0 if not present in pathways and remove the once not present in RNA-seq matrix

# %%
# Extract rownames from sce_symbol_filter
gene_names <- rownames(sce)

# Convert all_paths to a data frame if it's not already
all_paths_df <- as.data.frame(all_paths)

# Filter all_paths to retain only rows present in sce_symbol_filter
filtered_all_paths <- all_paths_df[rownames(all_paths_df) %in% gene_names, ]

# Identify genes in sce_symbol_filter not present in all_paths
missing_genes <- setdiff(gene_names, rownames(filtered_all_paths))

# Create a data frame of missing genes with all zeros
missing_genes_df <- as.data.frame(matrix(0, nrow=length(missing_genes), ncol=ncol(all_paths_df)))
rownames(missing_genes_df) <- missing_genes
colnames(missing_genes_df) <- colnames(all_paths_df)

# Combine filtered_all_paths and missing_genes_df
combined_paths <- rbind(filtered_all_paths, missing_genes_df)

# Reorder rows to match the order of genes in sce_symbol_filter
final_all_paths <- combined_paths[gene_names, ]

final_all_paths <- combined_paths[match(gene_names, rownames(combined_paths)), ]

final_all_paths <- as.matrix(final_all_paths)

# Print the resulting data frame
head(final_all_paths)
# Out:
#        IRIS_Bcell-Memory_IgG_IgA IRIS_Bcell-Memory_IgM IRIS_Bcell-naive
# SCYL3  0                         0                     0
# FIRRM  0                         0                     0
# FGR    0                         0                     0
# CFH    0                         0                     0
# STPG1  0                         0                     0
# NIPAL3 0                         0                     0
#        IRIS_CD4Tcell-N0 IRIS_CD4Tcell-Th1-restimulated12hour
# SCYL3  0                0
# FIRRM  0                0
# FGR    0                0
# CFH    0                0
# STPG1  0                0
# NIPAL3 0                0
#        IRIS_CD4Tcell-Th1-restimulated48hour
# SCYL3  0
# FIRRM  0
# FGR    0
# CFH    0
# STPG1  0
# NIPAL3 0
#        IRIS_CD4Tcell-Th2-restimulated12hour
# SCYL3  0
# FIRRM  0
# FGR    0
# CFH    0
# STPG1  0
# NIPAL3 0
#        IRIS_CD4Tcell-Th2-restimulated48hour IRIS_CD8Tcell-N0
# SCYL3  0                                    0
# FIRRM  0                                    0
# FGR    0                                    0
# CFH    0                                    0
# STPG1  0                                    0
# NIPAL3 0                                    0
#        IRIS_DendriticCell-Control ⋯ chr21_q21.1 chr21_q21.2 chr21_q21.3
# SCYL3  0                          ⋯ 0           0           0
# FIRRM  0                          ⋯ 0           0           0
# FGR    0                          ⋯ 0           0           0
# CFH    0                          ⋯ 0           0           0
# STPG1  0                          ⋯ 0           0           0
# NIPAL3 0                          ⋯ 0           0           0
#        chr21_q22.11 chr21_q22.12 chr21_q22.2 chr21_q22.13 chr21_q22.3 chr21_p12
# SCYL3  0            0            0           0            0           0
# FIRRM  0            0            0           0            0           0
# FGR    0            0            0           0            0           0
# CFH    0            0            0           0            0           0
# STPG1  0            0            0           0            0           0
# NIPAL3 0            0            0           0            0           0
#        chr21
# SCYL3  0
# FIRRM  0
# FGR    0
# CFH    0
# STPG1  0
# NIPAL3 0

# %% [markdown]
# # Run delayedPLIER

# %%
setAutoRealizationBackend("HDF5Array") #supportedRealizationBackends(), getRealizationBackend()

# Assign arguments to variables 
output_file_recount3 <- file.path(output_nb_path, 'recount3_model.rds')
output_dplier <- file.path(output_nb_path, 'recount3_model_r')

dir.create(output_dplier, showWarnings = F)

# Run PLIER (with common genes)
delayedPlier_result=.GlobalEnv$PLIER(data=sce, priorMat=final_all_paths, output_path = output_dplier)

# Prepare output directory
output_file_path=dirname(output_file_recount3)
dir.create(dirname(output_file_path), showWarnings = FALSE, recursive = TRUE)

# Save results
saveRDS(delayedPlier_result, file = output_file_recount3)
# Out:
# Removing 471 pathways with too few genes
#
# Computing SVD
#
# Using rsvd
#
# Done
#
# k is set to 160
# [1] 121.9623
# [1] "L2 is set to 121.96230977279"
# [1] "L1 is set to 60.9811548863949"
# errorY (SVD based:best possible) = 0.5415
#
# New L3 is 9.61116520613947e-05
#
# New L3 is 8.48182352464692e-05
#
# New L3 is 0.000108908769855066
#
# New L3 is 8.48182352464692e-05
#
# Bdiff is not decreasing
#
# New L3 is 9.61116520613947e-05
#
# Bdiff is not decreasing
#
# Bdiff is not decreasing
#
# Bdiff is not decreasing
#
# Bdiff is not decreasing
#
# Bdiff is not decreasing
#
# converged at  iteration 104 Bdiff is not decreasing
#
# There are 86  LVs with AUC>0.70
# Error in H5Fcreate(file): HDF5. File accessibility. Unable to open file.
# Traceback:
#
# 1. .GlobalEnv$PLIER(data = sce, priorMat = final_all_paths)
# 2. writeHDF5Array(out$residual, filepath = paste0(output_path, "residual.hdf5"),
#  .     name = "count")
# 3. HDF5RealizationSink(dim(x), sink_dimnames, type(x), as.sparse,
#  .     filepath = filepath, name = name, H5type = H5type, size = size,
#  .     chunkdim = chunkdim, level = level)
# 4. normalize_dump_filepath(filepath)
# 5. h5createFile(filepath)
# 6. H5Fcreate(file)

# %% [markdown]
# # Save as pickle

# %%
library(reticulate)

save_as_pickle <- function(object, filename, save_directory) {
  full_path <- file.path(save_directory, filename)
  py_save_object(r_to_py(object), full_path)
}

PLIER_model_to_pickle = function(PLIER_model, save_directory){
    
    # Check if the directory exists, create if it does not
    if (!dir.exists(save_directory)) {
      dir.create(save_directory, recursive = TRUE)
    }
    
    # Assuming gtex_tmp_1 is a list with various data types
    names_list <- names(PLIER_model)
    
    for (name in names_list) {
      element <- PLIER_model[[name]]
      if (is.matrix(element) || is.array(element)) {
        # Convert matrices/arrays to data frames before saving
        df <- as.data.frame(element)
        save_as_pickle(df, paste0(name, ".pkl"), save_directory)
      } else {
        # Save other data types directly
        save_as_pickle(element, paste0(name, ".pkl"), save_directory)
      }
    }  
}
